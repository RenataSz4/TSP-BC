# %% [markdown]
# # Concorde TSP Solver

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("bc_tsp_matrix.csv", index_col=0)

cities = df.index.tolist()
C = df.values.astype(int)

n = C.shape[0]

assert C.shape == (n, n)
assert np.allclose(C, C.T)
assert np.all(np.diag(C) == 0)

# %%
def write_tsplib_matrix(filename, matrix, name="baja_tsp"):
    n = matrix.shape[0]

    with open(filename, "w") as f:
        f.write(f"NAME: {name}\n")
        f.write("TYPE: TSP\n")
        f.write(f"DIMENSION: {n}\n")
        f.write("EDGE_WEIGHT_TYPE: EXPLICIT\n")
        f.write("EDGE_WEIGHT_FORMAT: FULL_MATRIX\n")
        f.write("EDGE_WEIGHT_SECTION\n")

        for i in range(n):
            row = " ".join(str(int(x)) for x in matrix[i])
            f.write(row + "\n")

        f.write("EOF\n")

# %%
tsp_file = "baja.tsp"
write_tsplib_matrix(tsp_file, C)

# %%
from concorde.tsp import TSPSolver
import time 

solver = TSPSolver.from_tspfile(tsp_file)

start_time = time.time()
solution = solver.solve()
end_time = time.time()
# Out:
# Problem Name: baja_tsp
# Problem Type: TSP
# Number of Nodes: 7
# Explicit Lengths (CC_MATRIXNORM)
# CCtsp_solve_dat ...
# Finding a good tour for compression ...
# linkern ...
# Less than 10 nodes, setting repeatcount to 0
# Setting kick type to close
# Starting Cycle: 916
# LK Cycle: 916
# Best cycle length: 916
# Lin-Kernighan Running Time: 0.00
# LK Initial Run: 916.0
# Less than 10 nodes, setting repeatcount to 0
# LK Run 0: 916.0
# Less than 10 nodes, setting repeatcount to 0
# LK Run from best tour: 916.0
# Time to find compression tour: 0.00 (seconds)
# Set initial upperbound to 916 (from tour)
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Fractional Matching: 916.0
# Initial Running Time: 0.00 (seconds)
# Basis Running Time: 0.00 (seconds)
# Total fractional matching time: 0.00 (seconds)
# Total Time for first_lp: 0.00 (seconds)
# Setting upperbound to the initial bound: 916.00
# Loading lp...done in 0.00 seconds
# LP has:  7 rows  7 columns  14 nonzeros
# Dual opt returned after 0.00 seconds
# Initial LP value: 916.000000
# Setting tolerances: next cuts 0.0100 next round 0.0010
# CCtsp_init_edgegenerator (50)
# Using junk-norm nearest code
#  21 edges
# LP has:  7 rows  7 columns  14 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  7 rows  7 columns  14 nonzeros
# Integral Solution of Value 916.00
# CCtsp_generate_edges (20021)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 1 calls)
# CCtsp_generate_edges (20021)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 2 calls)
# CCtsp_generate_edges (20021)
# Time for Add edges: 0.00 seconds (0.00 total in 1 calls)
# (SPARSE) 4 edges added, penalty 0.000000, val 916.000000
# Time for Sparse edge check: 0.00 seconds (0.00 total in 1 calls)
# Write Pool: 0 cuts
# Time for Cutting inside loop: 0.00 seconds (0.00 total in 1 calls)
# CCtsp_init_edgegenerator (-1)
# CCtsp_generate_edges (20021)
# Time for Add edges: 0.00 seconds (0.00 total in 2 calls)
# 0 edges added, penalty 0.000000
# New lower bound: 916.000000
# Time for Full edge check: 0.00 seconds (0.00 total in 1 calls)
# Time for Cutting Loop: 0.00 seconds (0.00 total in 1 calls)
# Number of outside rounds: 1
# CCtsp_x_greedy_tour ...
# 6 edges in x-tour
# tour length: 916.00 (0.00 seconds)
# Cannot run quadrant nearest with JUNK norms
# Trying 4-nearest instead
# Using junk-norm nearest code
#  17 edges
# Quad Nearest added 17 edges (0.00 seconds)
# Edgegen total edges: 17 (0.00 seconds)
# Less than 10 nodes, setting repeatcount to 0
# x-heuristic lk  gives: 916.00
# Exact Price Time: 0.00 seconds
# Exact lower bound: 916.000000
# DIFF: 0.000000
# Established Bound: 916
# Optimal tour: 916
# Total Time to solve TSP: 0.00

# %%
print(f"Solving time: {end_time - start_time} seconds")
# Out:
# Solving time: 0.0022759437561035156 seconds

# %%
tour_idx = solution.tour
tour_cities = [cities[i] for i in tour_idx]
tour_cities.append(tour_cities[0])  # close the loop

tour_cities
# Out:
# ['Tijuana, Baja California, Mexico',
#  'Tecate, Baja California, Mexico',
#  'Mexicali, Baja California, Mexico',
#  'San Felipe, Baja California, Mexico',
#  'San Quintin, Baja California, Mexico',
#  'Ensenada, Baja California, Mexico',
#  'Rosarito, Baja California, Mexico',
#  'Tijuana, Baja California, Mexico']

# %%
total_cost = sum(
    C[tour_idx[i], tour_idx[(i + 1) % n]]
    for i in range(n)
)

total_cost
# Out:
# np.int64(916)

# %%
total_cost_hours = total_cost / 60
total_cost_hours
# Out:
# np.float64(15.266666666666667)

# %% [markdown]
# # Test with more nodes (cities)

# %%
from concorde.tests.data_utils import get_dataset_path

fname = get_dataset_path("berlin52")
solver = TSPSolver.from_tspfile(fname)

solution = solver.solve()
# Out:
# Problem Name: berlin52
# Problem Type: TSP
# 52 locations in Berlin (Groetschel)
# Number of Nodes: 52
# Rounded Euclidean Norm (CC_EUCLIDEAN)
# CCtsp_solve_dat ...
# Finding a good tour for compression ...
# linkern ...
# Starting Cycle: 9951
#    0 Steps   Best: 7565   0.00 seconds
#    1 Steps   Best: 7542   0.00 seconds
#   26 Total Steps.
# Best cycle length: 7542
# Lin-Kernighan Running Time: 0.01
# LK Initial Run: 7542.0
# LK Run 0: 7542.0
# LK Run from best tour: 7542.0
# Time to find compression tour: 0.02 (seconds)
# Set initial upperbound to 7542 (from tour)
# Fractional Matching: 7197.0
# Initial Running Time: 0.00 (seconds)
# Basis Running Time: 0.00 (seconds)
# Total fractional matching time: 0.00 (seconds)
# Total Time for first_lp: 0.00 (seconds)
# Setting upperbound to the initial bound: 7542.00
# Loading lp...done in 0.00 seconds
# LP has:  52 rows  70 columns  140 nonzeros
# Dual opt returned after 0.00 seconds
# Initial LP value: 7197.000000
# Setting tolerances: next cuts 3.4500 next round 0.3450
# CCtsp_init_edgegenerator (50)
#  1325 edges
# LP has:  52 rows  70 columns  140 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  52 rows  70 columns  140 nonzeros
# Found  3 connect cuts in 0.00 seconds
#   Add  3 cuts (Total 1), LP: 7277.500000 (0.00 seconds)
# Found  0 segment cuts in 0.00 seconds
# Found  2 Fast Blossoms in 0.00 seconds
#   Add  2 cuts (Total 2), LP: 7296.000000 (0.00 seconds)
# integral solution not connected
# Found  0 Groetschel-Holland Blossoms in 0.00 seconds
# Block Combs
#   Type 0: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.00
# Found  0 block_combs in 0.00 seconds
# Found  3 exact subtours in 0.00 seconds
#   Add  3 cuts (Total 3), LP: 7424.500000 (0.00 seconds)
# Found  3 tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add  3 cuts (Total 5), LP: 7484.750000 (0.00 seconds)
# Found  1 CLOSE tighten_lp cuts (viol 0.1250) in 0.00 seconds
#   Add  1 cuts (Total 6), LP: 7497.500000 (0.00 seconds)
# Found  0 double deckers (viol -0.0000) in 0.00 seconds
# Found  0 CLOSE double deckers (viol -0.0000) in 0.00 seconds
# CCtsp_generate_edges (20156)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 1 calls)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 2 calls)
# CCtsp_generate_edges (20156)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 3 calls)
# CCtsp_generate_edges (20156)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 4 calls)
# CCtsp_generate_edges (20156)
# Time for Add edges: 0.00 seconds (0.00 total in 1 calls)
# (SPARSE) 119 edges added, penalty 0.000000, val 7164.000000
# Time for Sparse edge check: 0.00 seconds (0.00 total in 1 calls)
# Write Pool: 1 cuts
# Time for Cutting inside loop: 0.00 seconds (0.00 total in 1 calls)
# LP has:  58 rows  189 columns  667 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  58 rows  189 columns  514 nonzeros
# integral solution not connected
# Found  6 connect cuts in 0.00 seconds
#   Add  6 cuts (Total 7), LP: 7207.000000 (0.00 seconds)
# integral solution not connected
# Found  0 segment cuts in 0.00 seconds
# Found  0 Fast Blossoms in 0.00 seconds
# Found  0 Groetschel-Holland Blossoms in 0.00 seconds
# Block Combs
#   Type 0: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.00
# Found  0 block_combs in 0.00 seconds
# Found  1 exact subtours in 0.00 seconds
#   Add  1 cuts (Total 8), LP: 7542.000000 (0.00 seconds)
# Integral Solution of Value 7542.00
# CCtsp_generate_edges (20156)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 5 calls)
# CCtsp_generate_edges (20156)
# Time for Add edges: 0.00 seconds (0.00 total in 2 calls)
# (SPARSE) 1 edges added, penalty 0.000000, val 7542.000000
# Time for Sparse edge check: 0.00 seconds (0.00 total in 2 calls)
# Write Pool: 1 cuts
# Time for Cutting inside loop: 0.00 seconds (0.00 total in 2 calls)
# CCtsp_init_edgegenerator (-1)
# xprice_build
# xprice_reset (0)
# CCtsp_generate_edges (20156)
# Time for Add edges: 0.00 seconds (0.00 total in 3 calls)
# 0 edges added, penalty 0.000000
# New lower bound: 7542.000000
# Time for Full edge check: 0.00 seconds (0.00 total in 1 calls)
# Time for Cutting Loop: 0.00 seconds (0.00 total in 1 calls)
# Number of outside rounds: 1
# CCtsp_x_greedy_tour ...
# 51 edges in x-tour
# tour length: 7542.00 (0.00 seconds)
# Built CCkdtree: 0.00 (seconds)
#  233 edges
# Quad Nearest added 233 edges (0.00 seconds)
# Edgegen total edges: 233 (0.00 seconds)
# x-heuristic lk  gives: 7542.00
# Exact Price Time: 0.00 seconds
# Exact lower bound: 7542.000000
# DIFF: 0.000000
# Established Bound: 7542
# Optimal tour: 7542
# Total Time to solve TSP: 0.04
